# %% [markdown]
# ***
# **Data: I am looking to analyse the data of plane crashes from the timespan of 2010 - 2024**
#
# **Goal: I am trying to find out what is the most horrific plane crash of them all**
#
# **Source: https://www.kaggle.com/datasets/luiscfrancisco/plane-crashes-dataset**
#
# **Access: The data is available publicly**
#
# **Access Method:.csv**

# %% [markdown]
# ***
# **FUNCTIONAL REQUIREMENTS**

# %% [markdown]
# **Data Loading:**
# Description = Load the dataset and read into pandas data frame
#
# Input =
#
# Output =
#
# **Data Cleaning:**
#
# Description = The sytstem needs to handle missing values and allow filtering, sorting and grouping of data
#
# Input = Any year from 1907 - 2024
#
# Output = Gives data of that year
#
# **Data Analysis:**
#
# Description = The type of analysis that we will use in this data set will be mean, median, mode, and range
#
# Input = Choose a year between 2000 - 2024 to find the avergae amount of crashes for that year
#
# Output = It will output the number of how many crashes happened in the year
#
# **Data Visualisation:**
# Description = The way the data will be shown (e.g. Pandas DataFrame / Matplotlib chart types)
#
# Input = Choose how you want to visualise the data
#
# Output = It will be visualised as you have chosen
#
# **Data Reporting:**
# Description = Collecting data and transferring it into a differnet .csv file
#
# Input = Choose where to store the data e.g. .csv or .txt
#
# Output = The data will be transferred to the type of file you choose

# %% [markdown]
# ***
# **USE CASES**
#
# **DATA LOADING**
#
# Actor: User
#
# Goal: To load a dataset into the system.
#
# Preconditions: User has a dataset file ready.
#
# Main Flow:
#
# User places the dataset for reading into the correct folder.
#
# System validates the file format.
#
# System loads the dataset and displays the information in a dataframe.
#
# Postconditions: Dataset is loaded and ready for analys
#
# **DATA CLEANING**
#
# Actor: User
#
# Goal: To load a dataset into the system.
#
# Preconditions: User has a dataset file ready.
#
# Main Flow:
#
# User places the dataset for reading into the correct folder.
#
# System validates the file format.
#
# System loads the dataset and displays the information in a dataframe.
#
# Postconditions: Dataset is loaded and ready for analys
#
# **DATA ANALYSIS**
#
# Actor: User
#
# Goal: To load a dataset into the system.
#
# Preconditions: User has a dataset file ready.
#
# Main Flow:
#
# User places the dataset for reading into the correct folder.
#
# System validates the file format.
#
# System loads the dataset and displays the information in a dataframe.
#
# Postconditions: Dataset is loaded and ready for analys
#
# **DATA VISUALISATION**
#
# Actor: User
#
# Goal: To load a dataset into the system.
#
# Preconditions: User has a dataset file ready.
# Main Flow:
#
# User places the dataset for reading into the correct folder.
# System validates the file format.
#
# System loads the dataset and displays the information in a dataframe.
#
# Postconditions: Dataset is loaded and ready for analys
#
# **DATA REPORTING**
#
# Actor: User
#
# Goal: To load a dataset into the system.
#
# Preconditions: User has a dataset file ready.
#
# Main Flow:
#
# User places the dataset for reading into the correct folder.
#
# System validates the file format.
#
# System loads the dataset and displays the information in a dataframe.
#
# Postconditions: Dataset is loaded and ready for analys

# %% [markdown]
# ***
# **NON FUNCTIONAL REQUIREMENTS**

# %% [markdown]
# **Usability: What is required from the User Interface and a 'README' document?**
#
# A comprehensive README document must include a title, an overview, and installation instructions, among other things. A "Getting started" or "Usage" section, a list of more useful resources, a contributor list, a license, and any other information you believe the users would find beneficial can also be added.
# **Reliability: What is required from the system when providing information to the user on errors and ensuring data integrity?**
#
# Turn on the logging. Data changes can be detected through logs. A log can assist in determining which data may have been impacted and even who is accountable for the change in situations where data was added, changed, or removed improperly or without authorization. Validate and confirm the data.
